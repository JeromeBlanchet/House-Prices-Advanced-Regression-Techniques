# %% [markdown]
# # Modelling House Prices
# ### by Jérôme Blanchet
#
#
# # Abstract
#
#
#
#
#
# # Table of Contents
#
# Part 1) Data Exploration ....................................................................................................XXX
# Part 2) Correlation Study....................................................................................................XXX.
# Part 3) Preprocessing the Data...............................................................................................XXX.
# Part 4) Modelling............................................................................................................XXX.

# %% [markdown]
# # Part 1) Data Exploration

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np
from scipy.stats import skew
from scipy.stats.stats import pearsonr
import seaborn as sns
from pandas import DataFrame
import time

import sys
print('Python: {}'.format(sys.version))
import scipy
print('scipy: {}'.format(scipy.__version__))
import numpy
print('numpy: {}'.format(numpy.__version__))
import matplotlib
print('matplotlib: {}'.format(matplotlib.__version__))
import pandas
print('pandas: {}'.format(pandas.__version__))
import sklearn
print('sklearn: {}'.format(sklearn.__version__))
# Out:
# Python: 3.5.2 |Anaconda 4.2.0 (64-bit)| (default, Jul  5 2016, 11:41:13) [MSC v.1900 64 bit (AMD64)]
# scipy: 0.18.1
# numpy: 1.11.1
# matplotlib: 1.5.3
# pandas: 0.18.1
# sklearn: 0.17.1

# %%
DATATRAIN = pd.read_csv("C:/Users/jeblanch/Documents/HP train.csv")
DATATEST = pd.read_csv("C:/Users/jeblanch/Documents/HP test.csv")
SCORE = pd.read_csv("C:/Users/jeblanch/Documents/SCORE HOUSE PRICES.csv")

# %%
plt.figure(figsize = (8, 4))
plt.title('Sale Price Distribution')
plt.xlabel('Sale Price')
plt.ylabel('Frequency')
sns.distplot(DATATRAIN['SalePrice'], kde = False, color = 'g', hist_kws={'alpha': 0.99})
xt = plt.xticks(rotation=45);

DATATRAIN['SalePrice_log'] = np.log1p(DATATRAIN["SalePrice"])
plt.figure(figsize = (8, 4))
plt.title('Sale Price Log Distribution')
plt.xlabel('Sale Price Log')
plt.ylabel('Frequency')
sns.distplot(DATATRAIN['SalePrice_log'], kde = False, color = 'g', hist_kws={'alpha': 0.99})
xt = plt.xticks(rotation=45);

# %%
numeric_feats = DATATRAIN.dtypes[DATATRAIN.dtypes != "object"].index
categorical_feats = DATATRAIN.dtypes[DATATRAIN.dtypes == "object"].index
numeric_feats
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice', 'SalePrice_log'],
#       dtype='object')

# %%
categorical_feats
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
skewed_feats = DATATRAIN[numeric_feats].apply(lambda x: skew(x.dropna())) 
skewed_feats = skewed_feats[skewed_feats > 0.75]
skewed_feats = skewed_feats.index

# %% [markdown]
# Work in Progress...
# Work in Progress...
# Work in Progress...
